# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as T
import torch.optim as optim
import torchvision.models as models
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
vgg = models.vgg11()
print(vgg)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
class myVGG(nn.Module):
    def __init__(self):
        super(myVGG,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.MaxPool2d(2,2,0,1),

            nn.Conv2d(64,128,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),

            nn.MaxPool2d(2,2,0,1),

            nn.Conv2d(128,256,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.Conv2d(256,256,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(True),

            nn.MaxPool2d(2,2,0,1,),

            nn.Conv2d(256,512,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),

            nn.Conv2d(512,512,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            #512x2x2
            nn.MaxPool2d(2,2,0,1),
            nn.Conv2d(512,512,kernel_size= 3,padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.Conv2d(512,512,kernel_size = 3,padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(True),

            nn.MaxPool2d(2,2,0,1),
        )

        # Initialize weights
        for m in self.modules():
            if isinstance(m,nn.Conv2d):
                n = m.kernel_size[0]*m.kernel_size[1]*m.out_channels
                m.weight.data.normal_(0,math.sqrt(2./n))
                m.bias.data.zero_()
                
        # self.avgpool = nn.AdaptiveAvgPool2d(output_size=(2,2))
        self.classifier = nn.Sequential(
            # nn.Linear(in_features=2*2*512,out_features=256,bias=True),
            # nn.ReLU(inplace=True),
            # nn.Dropout(p=0.5,inplace=False),    
            # nn.Linear(in_features=256,out_features=256,bias=True),
            # nn.ReLU(True),
            # nn.Dropout(p=0.5,inplace=False),
            # nn.Linear(in_features=256,out_features=10,bias=True)
            nn.Dropout(),
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(512,512),
            nn.ReLU(True),
            nn.Linear(512,10),
        )

    def forward(self,x):
        x = self.features(x)
        x = x.view(x.size(0),-1)
        x = self.classifier(x)
        return x

# %%
transforms = T.Compose([
                        T.RandomCrop((32,32),padding=(4,4)),
                        T.RandomHorizontalFlip(p=0.5),
                        T.ToTensor(),
                        T.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
                        
])

trainset = dsets.CIFAR10(root = '/content/drive/MyDrive/lab/VGGNET/datasets',train=True,transform=transforms,download=True)
testset = dsets.CIFAR10(root='/content/drive/MyDrive/lab/VGGNET/datasets',train=False,transform=T.Compose([         #T.RandomCrop((32,32),padding=(4,4)),
                                                                                                                    # T.RandomHorizontalFlip(p=0.5),
                                                                                                                    T.ToTensor(),
                                                                                                                    T.Normalize(mean=[0.485,0.456,0.406],
                                                                                                                                std = [0.229,0.224,0.225])
]),download=True)
classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainLoader = torch.utils.data.DataLoader(trainset,batch_size = 128,shuffle = True)
testLoader = torch.utils.data.DataLoader(testset,batch_size =128,shuffle=False,drop_last=True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

net = myVGG()
net = net.to(device)

# %%
criterion = nn.CrossEntropyLoss().cuda()
optimizer = optim.SGD(net.parameters(),lr=0.05,momentum=0.9,weight_decay=5e-4)
# scheduler = optim.lr_scheduler.StepLR(optimizer,step_size=10,gamma=0.5)

# %%
def check_accuracy(network,testLoader):
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in testLoader:
            images,labels = data
            images = images.cuda()
            labels = labels.cuda()
            outputs = network(images)
            #
            _,predicted = torch.max(outputs,1)
            c = (predicted == labels).squeeze()
            for i in range(128):
                label = labels[i]
                class_correct[label] +=c[i].item()
                class_total[label] +=1
    accuracy_sum = 0
    for i in range(10):
        temp = 100* class_correct[i] / class_total[i]
        accuracy_sum += temp
    return accuracy_sum / 10

# %%
def show_accuracy(network,testLoader):
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for data in testLoader:
            images,labels = data
            images = images.cuda()
            labels = labels.cuda()
            outputs = network(images)
            #
            _,predicted = torch.max(outputs,1)
            c = (predicted == labels).squeeze()
            for i in range(128):
                label = labels[i]
                class_correct[label] +=c[i].item()
                class_total[label] +=1
    accuracy_sum = 0
    for i in range(10):
        temp = 100* class_correct[i] / class_total[i]
        print('Accuracy of %5s : %2d %%'%(classes[i],temp))
        accuracy_sum += temp
    print('Accuracy average: ',accuracy_sum / 10)

# %%
def adjust_learning_rate(optimizer,epoch,lr):
    lr = lr*(0.5 **(epoch //30))
    for param_group in optimizer.param_groups:
        param_group['lr']=lr
    return lr

# %%
epochs_accuracy_list = [1e9]
epochs_accuracy = 0
lr = 0.05
for epoch in range(200):
    running_loss = 0.0
    avg_loss=0.0
    for i,data in enumerate(trainLoader,0):
        #get the inputs
        inputs,labels = data
        inputs,labels = inputs.to(device),labels.to(device)
        #zero the parameter gradients
        outputs = net(inputs)
        loss = criterion(outputs,labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # # print statistics
        # running_loss += loss.item()
        # avg_loss += loss.item()
        # if i%50 ==49:
        #     print('[%d,%5d] loss: %.3f'%(epoch+1,i+1,running_loss/50))
        #     running_loss=0.0

    # if abs(pre_avg_loss-avg_loss)<=0.01 and epoch!=0:
    #     print("learning rate 50% reduced.")
    #     scheduler.step()
    acc = check_accuracy(net,testLoader)
    epochs_accuracy += acc
    print("epoch: {} | Accuracy: {}".format(epoch,acc))
    if epoch % 5 == 0:
        show_accuracy(net,testLoader)
        epochs_accuracy_list.append(epochs_accuracy/5)
        epochs_accuracy = 0

print('Finished Training')
# Out:
# epoch: 0 | Accuracy: 49.462444965372285
# Accuracy of airplane : 35 %
# Accuracy of automobile : 46 %
# Accuracy of  bird : 30 %
# Accuracy of   cat : 14 %
# Accuracy of  deer : 41 %
# Accuracy of   dog : 44 %
# Accuracy of  frog : 73 %
# Accuracy of horse : 63 %
# Accuracy of  ship : 68 %
# Accuracy of truck : 74 %
# Accuracy average:  49.26225437367748
# epoch: 1 | Accuracy: 62.09555878636489
# epoch: 2 | Accuracy: 65.98003807973978
# epoch: 3 | Accuracy: 71.46760918863642
# epoch: 4 | Accuracy: 73.9502469034261
# epoch: 5 | Accuracy: 75.81359701144311
# Accuracy of airplane : 78 %
# Accuracy of automobile : 81 %
# Accuracy of  bird : 59 %
# Accuracy of   cat : 43 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 82 %
# Accuracy of horse : 80 %
# Accuracy of  ship : 83 %
# Accuracy of truck : 92 %
# Accuracy average:  75.77343632923642
# epoch: 6 | Accuracy: 77.97984170090578
# epoch: 7 | Accuracy: 78.42167768892907
# epoch: 8 | Accuracy: 79.6636433655783
# epoch: 9 | Accuracy: 79.93492488788307
# epoch: 10 | Accuracy: 80.47241903171546
# Accuracy of airplane : 86 %
# Accuracy of automobile : 89 %
# Accuracy of  bird : 65 %
# Accuracy of   cat : 49 %
# Accuracy of  deer : 84 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 87 %
# Accuracy of horse : 86 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 91 %
# Accuracy average:  80.65305086710137
# epoch: 11 | Accuracy: 79.99536757662864
# epoch: 12 | Accuracy: 80.87631102931242
# epoch: 13 | Accuracy: 80.57380300381264
# epoch: 14 | Accuracy: 81.18594884118554
# epoch: 15 | Accuracy: 82.27740225919473
# Accuracy of airplane : 87 %
# Accuracy of automobile : 90 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 66 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 67 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 92 %
# Accuracy of truck : 90 %
# Accuracy average:  82.297161677751
# epoch: 16 | Accuracy: 82.07763461905935
# epoch: 17 | Accuracy: 82.04529752758448
# epoch: 18 | Accuracy: 81.72531658296728
# epoch: 19 | Accuracy: 81.30649143105956
# epoch: 20 | Accuracy: 82.77613923215823
# Accuracy of airplane : 81 %
# Accuracy of automobile : 85 %
# Accuracy of  bird : 79 %
# Accuracy of   cat : 68 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 86 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 94 %
# Accuracy average:  82.71606890106489
# epoch: 21 | Accuracy: 83.99850514751952
# epoch: 22 | Accuracy: 82.72065194880531
# epoch: 23 | Accuracy: 83.77087168631456
# epoch: 24 | Accuracy: 82.12026200124706
# epoch: 25 | Accuracy: 83.28810362350983
# Accuracy of airplane : 83 %
# Accuracy of automobile : 90 %
# Accuracy of  bird : 79 %
# Accuracy of   cat : 71 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 86 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 92 %
# Accuracy average:  83.27794294118239
# epoch: 26 | Accuracy: 82.70759371504496
# epoch: 27 | Accuracy: 83.61081265101177
# epoch: 28 | Accuracy: 84.15209417241114
# epoch: 29 | Accuracy: 82.51163479658656
# epoch: 30 | Accuracy: 82.3544718865353
# Accuracy of airplane : 87 %
# Accuracy of automobile : 91 %
# Accuracy of  bird : 77 %
# Accuracy of   cat : 59 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 70 %
# Accuracy of  frog : 89 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 84 %
# Accuracy of truck : 90 %
# Accuracy average:  82.14418131522194
# epoch: 31 | Accuracy: 84.63124217746832
# epoch: 32 | Accuracy: 84.42895636224723
# epoch: 33 | Accuracy: 84.53274721323655
# epoch: 34 | Accuracy: 83.54938713219101
# epoch: 35 | Accuracy: 83.56894641265912
# Accuracy of airplane : 81 %
# Accuracy of automobile : 90 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 72 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 82 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 92 %
# Accuracy average:  83.5993375659988
# epoch: 36 | Accuracy: 84.79339874737846
# epoch: 37 | Accuracy: 85.05245770710259
# epoch: 38 | Accuracy: 83.81191457512189
# epoch: 39 | Accuracy: 82.53977129220766
# epoch: 40 | Accuracy: 84.272685526615
# Accuracy of airplane : 85 %
# Accuracy of automobile : 93 %
# Accuracy of  bird : 81 %
# Accuracy of   cat : 68 %
# Accuracy of  deer : 82 %
# Accuracy of   dog : 74 %
# Accuracy of  frog : 82 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 88 %
# Accuracy average:  84.04227471488107
# epoch: 41 | Accuracy: 84.80243642118107
# epoch: 42 | Accuracy: 84.70301744308475
# epoch: 43 | Accuracy: 82.97188333943116
# epoch: 44 | Accuracy: 83.70153473721035
# epoch: 45 | Accuracy: 84.35013902890493
# Accuracy of airplane : 84 %
# Accuracy of automobile : 90 %
# Accuracy of  bird : 82 %
# Accuracy of   cat : 64 %
# Accuracy of  deer : 89 %
# Accuracy of   dog : 78 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 88 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 92 %
# Accuracy average:  84.4904299014222
# epoch: 46 | Accuracy: 83.92213594039987
# epoch: 47 | Accuracy: 83.70188558924531
# epoch: 48 | Accuracy: 84.71101032115949
# epoch: 49 | Accuracy: 84.90305657939231
# epoch: 50 | Accuracy: 85.61494394354757
# Accuracy of airplane : 85 %
# Accuracy of automobile : 87 %
# Accuracy of  bird : 78 %
# Accuracy of   cat : 74 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 78 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 91 %
# Accuracy of  ship : 94 %
# Accuracy of truck : 92 %
# Accuracy average:  85.64541602076085
# epoch: 51 | Accuracy: 85.0733180443475
# epoch: 52 | Accuracy: 84.79107301211602
# epoch: 53 | Accuracy: 85.14265712375008
# epoch: 54 | Accuracy: 83.24631748330542
# epoch: 55 | Accuracy: 85.62444169564185
# Accuracy of airplane : 90 %
# Accuracy of automobile : 94 %
# Accuracy of  bird : 74 %
# Accuracy of   cat : 72 %
# Accuracy of  deer : 87 %
# Accuracy of   dog : 78 %
# Accuracy of  frog : 93 %
# Accuracy of horse : 90 %
# Accuracy of  ship : 90 %
# Accuracy of truck : 85 %
# Accuracy average:  85.82486273834915
# epoch: 56 | Accuracy: 84.76230468400634
# epoch: 57 | Accuracy: 84.60243467329295
# epoch: 58 | Accuracy: 84.4026770426847
# epoch: 59 | Accuracy: 85.38265810790418
# epoch: 60 | Accuracy: 84.01016023434445
# Accuracy of airplane : 80 %
# Accuracy of automobile : 91 %
# Accuracy of  bird : 78 %
# Accuracy of   cat : 69 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 87 %
# Accuracy of horse : 87 %
# Accuracy of  ship : 86 %
# Accuracy of truck : 91 %
# Accuracy average:  83.97951834876787
# epoch: 61 | Accuracy: 84.57199395285562
# epoch: 62 | Accuracy: 83.98039950861951
# epoch: 63 | Accuracy: 84.13483453711177
# epoch: 64 | Accuracy: 84.09125248976875
# epoch: 65 | Accuracy: 85.69478239797014
# Accuracy of airplane : 86 %
# Accuracy of automobile : 93 %
# Accuracy of  bird : 79 %
# Accuracy of   cat : 68 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 82 %
# Accuracy of  frog : 87 %
# Accuracy of horse : 90 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 88 %
# Accuracy average:  85.59489266868209
# epoch: 66 | Accuracy: 86.20606705261451
# epoch: 67 | Accuracy: 84.59280809702997
# epoch: 68 | Accuracy: 83.83039036300639
# epoch: 69 | Accuracy: 84.1010133745261
# epoch: 70 | Accuracy: 84.0491748341568
# Accuracy of airplane : 88 %
# Accuracy of automobile : 95 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 61 %
# Accuracy of  deer : 86 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 87 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 86 %
# Accuracy of truck : 90 %
# Accuracy average:  84.4499669702446
# epoch: 71 | Accuracy: 83.60321802472941
# epoch: 72 | Accuracy: 83.7388259897053
# epoch: 73 | Accuracy: 84.27096169616411
# epoch: 74 | Accuracy: 85.48512488703922
# epoch: 75 | Accuracy: 85.28255613919296
# Accuracy of airplane : 88 %
# Accuracy of automobile : 93 %
# Accuracy of  bird : 77 %
# Accuracy of   cat : 77 %
# Accuracy of  deer : 88 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 90 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 89 %
# Accuracy of truck : 90 %
# Accuracy average:  85.70328809479948
# epoch: 76 | Accuracy: 83.85835293002805
# epoch: 77 | Accuracy: 84.35145365339893
# epoch: 78 | Accuracy: 84.7123446232628
# epoch: 79 | Accuracy: 84.04053983014599
# epoch: 80 | Accuracy: 84.68420324292711
# Accuracy of airplane : 87 %
# Accuracy of automobile : 88 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 76 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 77 %
# Accuracy of  frog : 88 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 91 %
# Accuracy average:  84.80468452659791
# epoch: 81 | Accuracy: 83.4012034620615
# epoch: 82 | Accuracy: 85.27387878593223
# epoch: 83 | Accuracy: 85.93374017247538
# epoch: 84 | Accuracy: 86.33582558689487
# epoch: 85 | Accuracy: 83.30022867791341
# Accuracy of airplane : 80 %
# Accuracy of automobile : 94 %
# Accuracy of  bird : 84 %
# Accuracy of   cat : 81 %
# Accuracy of  deer : 83 %
# Accuracy of   dog : 56 %
# Accuracy of  frog : 81 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 88 %
# Accuracy average:  83.21004833719174
# epoch: 86 | Accuracy: 84.6822342324918
# epoch: 87 | Accuracy: 85.16262598763572
# epoch: 88 | Accuracy: 84.8441821187543
# epoch: 89 | Accuracy: 84.963589599674
# epoch: 90 | Accuracy: 85.22454266086316
# Accuracy of airplane : 81 %
# Accuracy of automobile : 92 %
# Accuracy of  bird : 80 %
# Accuracy of   cat : 72 %
# Accuracy of  deer : 89 %
# Accuracy of   dog : 79 %
# Accuracy of  frog : 81 %
# Accuracy of horse : 89 %
# Accuracy of  ship : 93 %
# Accuracy of truck : 88 %
# Accuracy average:  85.11449242984932
# epoch: 91 | Accuracy: 85.49516386256389
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-bb18ea23b825> in <module>()
#       5     running_loss = 0.0
#       6     avg_loss=0.0
# ----> 7     for i,data in enumerate(trainLoader,0):
#       8         #get the inputs
#       9         inputs,labels = data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     118
#     119         if self.transform is not None:
# --> 120             img = self.transform(img)
#     121
#     122         if self.target_transform is not None:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in forward(self, img)
#     582         """
#     583         if self.padding is not None:
# --> 584             img = F.pad(img, self.padding, self.fill, self.padding_mode)
#     585
#     586         width, height = F._get_image_size(img)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py in pad(img, padding, fill, padding_mode)
#     424     """
#     425     if not isinstance(img, torch.Tensor):
# --> 426         return F_pil.pad(img, padding=padding, fill=fill, padding_mode=padding_mode)
#     427
#     428     return F_t.pad(img, padding=padding, fill=fill, padding_mode=padding_mode)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional_pil.py in pad(img, padding, fill, padding_mode)
#     133         raise TypeError("Got inappropriate padding_mode arg")
#     134
# --> 135     if isinstance(padding, list):
#     136         padding = tuple(padding)
#     137
#
# KeyboardInterrupt:

# %%
# with torch.no_grad():
#     for data in testLoader:
#         images,labels = data
#         images = images.cuda()
#         labels = labels.cuda()
#         outputs = net(images)
#         print(outputs.shape)
#         #values , indices -> max 값, max값이 나온 index => 따라서 indices 가 predicted label 이다.
#         _,predicted = torch.max(outputs,1)
#         # predicted == labels 에 대한 T/F인 Tensor return.
#         c = (predicted == labels).squeeze()
#         print(c)
#         for i in range(16):
#             # i번째 image 에 대한 label 값
#             label = labels[i]
#             # 해당 label에서 c가 True면 1이 + 되고, False면 0이 +된다.
#             class_correct[label] += c[i].item()
#             # 해당 label의 total 개수에 +1 을 해준다.
#             class_total[label] += 1
# accuracy_sum =0
# for i in range(10):
#     temp = 100 * class_correct[i] / class_total[i]
#     print('Accuracy of %5s : %2d %%'%(classes[i],temp))
#     accuracy_sum += temp
# print('Acuuray average: ',accuracy_sum/10)

# %%
print(epochs_accuracy_list[1:])

# %% [markdown]
# [10.040672865322454, 70.15013582605908, 79.31101481981395, 81.79505396785984, 82.59884132969259, 83.4814135250621, 83.15882949889385, 83.80298047842317, 83.50835712860939, 84.1718935578453, 84.45785644493183, 84.59597714384635, 84.7158831296548, 84.63045622414111, 84.66939719600728, 84.69449581442356, 84.39125527821275, 84.36223007114548, 84.70470497465342, 84.91304034527408, 84.89556122273231]

# %%
import matplotlib.pyplot as plt

# %%
data = [10.040672865322454, 70.15013582605908, 79.31101481981395, 81.79505396785984, 82.59884132969259, 83.4814135250621, 83.15882949889385, 83.80298047842317, 83.50835712860939, 84.1718935578453, 84.45785644493183, 84.59597714384635, 84.7158831296548, 84.63045622414111, 84.66939719600728, 84.69449581442356, 84.39125527821275, 84.36223007114548, 84.70470497465342, 84.91304034527408, 84.89556122273231]

# %%
x=[]
for i in range(len(data)):
    x.append(i*5)

# %%
plt.title("VGG11 + CIFAR10")
plt.plot(x,data)
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.show()
